# %%
import os
import numpy as np
from sklearn.metrics import balanced_accuracy_score
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
train_images_dir = 'train_images_dir'
train_masks_dir  = 'train_mask_dir'
test_dir         = 'test_dir'
img_size         = (128, 128)
batch_size       = 8
epochs           = 100

# %%
def load_dataset(images_dir, masks_dir, img_size):
    X, Y = [], []
    for fname in sorted(os.listdir(images_dir)):
        if not fname.lower().endswith('.jpg'):
            continue
        # Imagen en gris, normalizada a [0,1]
        img = load_img(os.path.join(images_dir, fname),
                       target_size=img_size,
                       color_mode='grayscale')
        img = img_to_array(img) / 255.0  # dtype float32
        # Máscara, umbral y cast a float32
        mask = load_img(os.path.join(masks_dir, fname.replace('.jpg','.png')),
                        target_size=img_size,
                        color_mode='grayscale')
        mask = img_to_array(mask) / 255.0
        mask = (mask > 0.5).astype('float32')    # <-- aquí

        X.append(img)
        Y.append(mask)
    return np.stack(X), np.stack(Y)

# %%
def load_test_dataset(test_dir, img_size):
    X, Y = [], []
    for fname in sorted(os.listdir(test_dir)):
        if not fname.lower().endswith('.jpg'):
            continue
        img = load_img(os.path.join(test_dir, fname),
                       target_size=img_size,
                       color_mode='grayscale')
        img = img_to_array(img) / 255.0
        mask = load_img(os.path.join(test_dir, fname.replace('.jpg','.png')),
                        target_size=img_size,
                        color_mode='grayscale')
        mask = img_to_array(mask) / 255.0
        mask = (mask > 0.5).astype(np.uint8)
        X.append(img)
        Y.append(mask)
    return np.stack(X), np.stack(Y)

# %%
def unet_model(input_shape):
    inputs = Input(input_shape)

    # Encoder
    c1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, 3, activation='relu', padding='same')(c1)
    p1 = MaxPooling2D()(c1)

    c2 = Conv2D(128, 3, activation='relu', padding='same')(p1)
    c2 = Conv2D(128, 3, activation='relu', padding='same')(c2)
    p2 = MaxPooling2D()(c2)

    c3 = Conv2D(256, 3, activation='relu', padding='same')(p2)
    c3 = Conv2D(256, 3, activation='relu', padding='same')(c3)
    p3 = MaxPooling2D()(c3)

    # Bottleneck
    c4 = Conv2D(512, 3, activation='relu', padding='same')(p3)
    c4 = Conv2D(512, 3, activation='relu', padding='same')(c4)

    # Decoder
    u5 = Conv2DTranspose(256, 2, strides=2, padding='same')(c4)
    u5 = concatenate([u5, c3])
    c5 = Conv2D(256, 3, activation='relu', padding='same')(u5)
    c5 = Conv2D(256, 3, activation='relu', padding='same')(c5)

    u6 = Conv2DTranspose(128, 2, strides=2, padding='same')(c5)
    u6 = concatenate([u6, c2])
    c6 = Conv2D(128, 3, activation='relu', padding='same')(u6)
    c6 = Conv2D(128, 3, activation='relu', padding='same')(c6)

    u7 = Conv2DTranspose(64, 2, strides=2, padding='same')(c6)
    u7 = concatenate([u7, c1])
    c7 = Conv2D(64, 3, activation='relu', padding='same')(u7)
    c7 = Conv2D(64, 3, activation='relu', padding='same')(c7)

    outputs = Conv2D(1, 1, activation='sigmoid')(c7)
    return Model(inputs, outputs)

# %%
X_train, y_train = load_dataset(train_images_dir, train_masks_dir, img_size)
X_test,  y_test  = load_test_dataset(test_dir, img_size)

# %%
class BalancedAccuracy(tf.keras.metrics.Metric):
    def __init__(self, name='balanced_accuracy', **kwargs):
        super().__init__(name=name, **kwargs)
        # fuerza dtype float32
        self.tp = self.add_weight(name='tp', shape=(), dtype=tf.float32, initializer='zeros')
        self.tn = self.add_weight(name='tn', shape=(), dtype=tf.float32, initializer='zeros')
        self.fp = self.add_weight(name='fp', shape=(), dtype=tf.float32, initializer='zeros')
        self.fn = self.add_weight(name='fn', shape=(), dtype=tf.float32, initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.cast(y_pred > 0.5, tf.float32)
        y_true = tf.cast(y_true, tf.float32)

        # suma los TP, TN, FP, FN convirtiendo antes a float
        self.tp.assign_add(tf.reduce_sum(tf.cast(
            tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 1)), tf.float32)))
        self.tn.assign_add(tf.reduce_sum(tf.cast(
            tf.logical_and(tf.equal(y_true, 0), tf.equal(y_pred, 0)), tf.float32)))
        self.fp.assign_add(tf.reduce_sum(tf.cast(
            tf.logical_and(tf.equal(y_true, 0), tf.equal(y_pred, 1)), tf.float32)))
        self.fn.assign_add(tf.reduce_sum(tf.cast(
            tf.logical_and(tf.equal(y_true, 1), tf.equal(y_pred, 0)), tf.float32)))

    def result(self):
        sens = self.tp / (self.tp + self.fn + 1e-7)
        spec = self.tn / (self.tn + self.fp + 1e-7)
        return (sens + spec) / 2

    def reset_states(self):
        for v in self.variables:
            v.assign(0.0)

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# %%
model = unet_model((128, 128, 1))
model.compile(optimizer='adam', loss=dice_loss, metrics=['accuracy', BalancedAccuracy()])

# %%
model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.1
)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.0257 - balanced_accuracy: 0.5040 - loss: 0.9657 - val_accuracy: 0.0198 - val_balanced_accuracy: 0.5088 - val_loss: 0.9957
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.0345 - balanced_accuracy: 0.5068 - loss: 0.9655 - val_accuracy: 0.0191 - val_balanced_accuracy: 0.5085 - val_loss: 0.9957
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.0391 - balanced_accuracy: 0.5109 - loss: 0.9654 - val_accuracy: 0.5950 - val_balanced_accuracy: 0.7828 - val_loss: 0.9957
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.6214 - balanced_accuracy: 0.7568 - loss: 0.9651 - val_accuracy: 0.6816 - val_balanced_accuracy: 0.7835 - val_loss: 0.9956
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.7144 - balanced_accuracy: 0.7637 - loss: 0.9647 - val_accuracy: 0.7980 - val_balanced_accuracy: 0.7562 - val_loss: 0.9955
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8175 - balanced_accuracy: 0.7311 - loss: 0.9641 - val_accuracy: 0.8157 - val_balanced_accuracy: 0.7793 - val_loss: 0.9954
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8486 - balanced_accuracy: 0.7444 - loss: 0.9632 - val_accuracy: 0.9857 - val_balanced_accuracy: 0.5937 - val_loss: 0.9951
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9776 - balanced_accuracy: 0.5431 - loss: 0.9617 - val_accuracy: 0.3192 - val_balanced_accuracy: 0.6589 - val_loss: 0.9949
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.3885 - balanced_accuracy: 0.6820 - loss: 0.9600 - val_accuracy: 0.9978 - val_balanced_accuracy: 0.5000 - val_loss: 0.9948
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9818 - balanced_accuracy: 0.4998 - loss: 0.9606 - val_accuracy: 0.9977 - val_balanced_accuracy: 0.4999 - val_loss: 0.9937
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9792 - balanced_accuracy: 0.5001 - loss: 0.9539 - val_accuracy: 0.2761 - val_balanced_accuracy: 0.6373 - val_loss: 0.9941
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.3623 - balanced_accuracy: 0.6720 - loss: 0.9540 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 0.9917
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9793 - balanced_accuracy: 0.5019 - loss: 0.9417 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5143 - val_loss: 0.9894
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9794 - balanced_accuracy: 0.5053 - loss: 0.9283 - val_accuracy: 0.2681 - val_balanced_accuracy: 0.6332 - val_loss: 0.9937
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.3610 - balanced_accuracy: 0.6730 - loss: 0.9477 - val_accuracy: 0.9982 - val_balanced_accuracy: 0.6000 - val_loss: 0.9809
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9802 - balanced_accuracy: 0.5310 - loss: 0.8738 - val_accuracy: 0.8253 - val_balanced_accuracy: 0.8839 - val_loss: 0.9874
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9503 - balanced_accuracy: 0.9419 - loss: 0.8838 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 0.9989
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9926 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 0.9998
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9980 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 0.9999
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9988 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 1.0000
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9992 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 1.0000
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9994 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 1.0000
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9996 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 1.0000
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9996 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 1.0000
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9997 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 1.0000
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9997 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 1.0000
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9996 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 1.0000
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9996 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 1.0000
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9995 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 0.9999
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9990 - val_accuracy: 0.9979 - val_balanced_accuracy: 0.5000 - val_loss: 0.9884
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9822 - balanced_accuracy: 0.5000 - loss: 0.9685 - val_accuracy: 0.0062 - val_balanced_accuracy: 0.5020 - val_loss: 0.9957
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.0219 - balanced_accuracy: 0.5021 - loss: 0.9647 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.0178 - balanced_accuracy: 0.5000 - loss: 0.9650 - val_accuracy: 0.0021 - val_balanced_accuracy: 0.5000 - val_loss: 0.9957

# %%
y_pred        = model.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(np.uint8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step

# %%
plt.imsave("pred_unet.jpg", y_pred_binary.squeeze(), cmap='gray')
